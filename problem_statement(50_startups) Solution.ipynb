# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as seabornInstance
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

# %%
dataset = pd.read_csv('50_Startups.csv')

# %%
dataset.shape
# Out:
# (50, 5)

# %%
dataset.describe()
# Out:
#             R&DSpend  Administration  MarketingSpend         Profit
# count      50.000000       50.000000       50.000000      50.000000
# mean    73721.615600   121344.639600   211025.097800  112012.639200
# std     45902.256482    28017.802755   122290.310726   40306.180338
# min         0.000000    51283.140000        0.000000   14681.400000
# 25%     39936.370000   103730.875000   129300.132500   90138.902500
# 50%     73051.080000   122699.795000   212716.240000  107978.190000
# 75%    101602.800000   144842.180000   299469.085000  139765.977500
# max    165349.200000   182645.560000   471784.100000  192261.830000

# %%
dataset.corr()
# Out:
#                 R&DSpend  Administration  MarketingSpend    Profit
# R&DSpend        1.000000        0.241955        0.724248  0.972900
# Administration  0.241955        1.000000       -0.032154  0.200717
# MarketingSpend  0.724248       -0.032154        1.000000  0.747766
# Profit          0.972900        0.200717        0.747766  1.000000

# %%
import seaborn as sns
sns.pairplot(dataset)

# %%
dataset.isnull().any()
# Out:
# R&DSpend          False
# Administration    False
# MarketingSpend    False
# State             False
# Profit            False
# dtype: bool

# %%
dataset.columns
# Out:
# Index(['R&DSpend', 'Administration', 'MarketingSpend', 'State', 'Profit'], dtype='object')

# %%
X= dataset[['R&DSpend','Administration','MarketingSpend']].values.reshape(-1,3)
print(X)
# Out:
# [[ 165349.2   136897.8   471784.1 ]
#  [ 162597.7   151377.59  443898.53]
#  [ 153441.51  101145.55  407934.54]
#  [ 144372.41  118671.85  383199.62]
#  [ 142107.34   91391.77  366168.42]
#  [ 131876.9    99814.71  362861.36]
#  [ 134615.46  147198.87  127716.82]
#  [ 130298.13  145530.06  323876.68]
#  [ 120542.52  148718.95  311613.29]
#  [ 123334.88  108679.17  304981.62]
#  [ 101913.08  110594.11  229160.95]
#  [ 100671.96   91790.61  249744.55]
#  [  93863.75  127320.38  249839.44]
#  [  91992.39  135495.07  252664.93]
#  [ 119943.24  156547.42  256512.92]
#  [ 114523.61  122616.84  261776.23]
#  [  78013.11  121597.55  264346.06]
#  [  94657.16  145077.58  282574.31]
#  [  91749.16  114175.79  294919.57]
#  [  86419.7   153514.11       0.  ]
#  [  76253.86  113867.3   298664.47]
#  [  78389.47  153773.43  299737.29]
#  [  73994.56  122782.75  303319.26]
#  [  67532.53  105751.03  304768.73]
#  [  77044.01   99281.34  140574.81]
#  [  64664.71  139553.16  137962.62]
#  [  75328.87  144135.98  134050.07]
#  [  72107.6   127864.55  353183.81]
#  [  66051.52  182645.56  118148.2 ]
#  [  65605.48  153032.06  107138.38]
#  [  61994.48  115641.28   91131.24]
#  [  61136.38  152701.92   88218.23]
#  [  63408.86  129219.61   46085.25]
#  [  55493.95  103057.49  214634.81]
#  [  46426.07  157693.92  210797.67]
#  [  46014.02   85047.44  205517.64]
#  [  28663.76  127056.21  201126.82]
#  [  44069.95   51283.14  197029.42]
#  [  20229.59   65947.93  185265.1 ]
#  [  38558.51   82982.09  174999.3 ]
#  [  28754.33  118546.05  172795.67]
#  [  27892.92   84710.77  164470.71]
#  [  23640.93   96189.63  148001.11]
#  [  15505.73  127382.3    35534.17]
#  [  22177.74  154806.14   28334.72]
#  [   1000.23  124153.04    1903.93]
#  [   1315.46  115816.21  297114.46]
#  [      0.    135426.92       0.  ]
#  [    542.05   51743.15       0.  ]
#  [      0.    116983.8    45173.06]]

# %%
Y= dataset['Profit'].values.reshape(-1,1)
print(Y)
# Out:
# [[ 192261.83]
#  [ 191792.06]
#  [ 191050.39]
#  [ 182901.99]
#  [ 166187.94]
#  [ 156991.12]
#  [ 156122.51]
#  [ 155752.6 ]
#  [ 152211.77]
#  [ 149759.96]
#  [ 146121.95]
#  [ 144259.4 ]
#  [ 141585.52]
#  [ 134307.35]
#  [ 132602.65]
#  [ 129917.04]
#  [ 126992.93]
#  [ 125370.37]
#  [ 124266.9 ]
#  [ 122776.86]
#  [ 118474.03]
#  [ 111313.02]
#  [ 110352.25]
#  [ 108733.99]
#  [ 108552.04]
#  [ 107404.34]
#  [ 105733.54]
#  [ 105008.31]
#  [ 103282.38]
#  [ 101004.64]
#  [  99937.59]
#  [  97483.56]
#  [  97427.84]
#  [  96778.92]
#  [  96712.8 ]
#  [  96479.51]
#  [  90708.19]
#  [  89949.14]
#  [  81229.06]
#  [  81005.76]
#  [  78239.91]
#  [  77798.83]
#  [  71498.49]
#  [  69758.98]
#  [  65200.33]
#  [  64926.08]
#  [  49490.75]
#  [  42559.73]
#  [  35673.41]
#  [  14681.4 ]]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
lm= LinearRegression()
lm.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(lm.coef_)
# Out:
# [[ 0.84691776 -0.04676962  0.01232223]]

# %%
Y_pred = lm.predict(X_test)

# %%
print(lm.intercept_)
# Out:
# [ 54209.6592437]

# %%
plt.scatter(dataset['Profit'],dataset['R&DSpend'])

# %%
dataset.corr()
# Out:
#                 R&DSpend  Administration  MarketingSpend    Profit
# R&DSpend        1.000000        0.241955        0.724248  0.972900
# Administration  0.241955        1.000000       -0.032154  0.200717
# MarketingSpend  0.724248       -0.032154        1.000000  0.747766
# Profit          0.972900        0.200717        0.747766  1.000000

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.4)

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()

model = lm.fit(X_train,Y_train)

# %%
print(lm.intercept_)
# Out:
# [ 62288.36012015]

# %%
print(lm.coef_)
# Out:
# [[ 0.76965162 -0.07052074  0.01285421]]

# %%
model.score(X_train,Y_train)  #R^2 value
# Out:
# 0.95722855554312936

# %%
predictions = model.predict(X_test)

# %%
plt.scatter(Y_test,predictions)

# %%
from sklearn import metrics

# %%
print('MAE',metrics.mean_absolute_error(Y_test,predictions))
# Out:
# MAE 8350.19693498

# %%
print('MSE',metrics.mean_squared_error(Y_test,predictions))
# Out:
# MSE 149335059.314

# %%
print('RMSE',np.sqrt(metrics.mean_squared_error(Y_test,predictions)))
# Out:
# RMSE 12220.272473

# %%
import pylab

# %%
Y1 = np.sin(X)
pylab.plot(X,Y1)
print(Y1)
# Out:
# [[ 0.7804944  -0.23913298 -0.99081551]
#  [ 0.99019149  0.05198977 -0.79123486]
#  [-0.15772524 -0.91960546 -0.95392869]
#  [-0.49653669  0.97093415  0.65522901]
#  [ 0.51234013  0.29732104 -0.08814629]
#  [-0.76844808  0.0282064   0.90240771]
#  [-0.9771021   0.43836966 -0.99655273]
#  [ 11.24182332  11.64278901  12.60707605]
#  [ 11.26944489  11.94323556  12.61066167]
#  [ 11.21174686  11.71817181  12.62254119]
#  [ 11.12036469  11.56884284  12.62730851]
#  [ 11.2521321   11.50571292  11.85349508]
#  [ 11.07697089  11.84620088  11.83473806]
#  [ 11.22961874  11.87851244  11.80596867]
#  [ 11.18591473  11.75872678  12.77474391]
#  [ 11.09819032  12.11530272  11.67969505]
#  [ 11.09141451  11.93840272  11.58187655]
#  [ 11.03480063  11.65824826  11.42005594]
#  [ 11.02086239  11.93624306  11.38756891]
#  [ 11.05735888  11.76926864  10.73824822]
#  [ 10.92402928  11.54304227  12.2766933 ]
#  [ 10.74561643  11.96841122  12.25865404]
#  [ 10.73670141  11.3509645   12.23328715]
#  [ 10.26338889  11.75238487  12.21169093]
#  [ 10.69353342  10.84511732  12.19110834]
#  [  9.91490166  11.09662077  12.12954305]
#  [ 10.55993211  11.32638008  12.07253725]
#  [ 10.26654364  11.68305677  12.05986508]
#  [ 10.23612817  11.34699803  12.01048778]
#  [ 10.07073481  11.47407683  11.90497505]
#  [  9.64896491  11.75494808  10.47825005]
#  [ 10.00684436  11.9499289   10.25184319]
#  [  6.90798525  11.72927028   7.55167545]
#  [  7.18194169  11.65975982  12.60187273]
#  [        -inf  11.81618744         -inf]
#  [  6.29535825  10.85404734         -inf]
#  [        -inf  11.66979074  10.71825617]]
# C:\Users\DELL\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.

# %%
import statsmodels.api as sm
#4.Normal distribution of error terms:
model = sm.OLS(Y_train,X_train).fit()
res = model.resid #residuals
fig = sm.qqplot(res,fit=True,line='45')
plt.show()  #Q-Qplot for the advertising data set

# %%
mod= sm.OLS(Y_train,X_train) #5.Little or No autocorrelation in the residuals:
results = mod.fit()
print(results.summary())  #Summary of the fitted Linear Model
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.988
# Model:                            OLS   Adj. R-squared (uncentered):              0.986
# Method:                 Least Squares   F-statistic:                              726.1
# Date:                Thu, 19 Mar 2020   Prob (F-statistic):                    6.51e-26
# Time:                        16:48:48   Log-Likelihood:                         -327.38
# No. Observations:                  30   AIC:                                      660.8
# Df Residuals:                      27   BIC:                                      665.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.6884      0.078      8.881      0.000       0.529       0.847
# x2             0.3389      0.042      8.162      0.000       0.254       0.424
# x3             0.0810      0.027      2.963      0.006       0.025       0.137
# ==============================================================================
# Omnibus:                        0.612   Durbin-Watson:                   2.499
# Prob(Omnibus):                  0.736   Jarque-Bera (JB):                0.679
# Skew:                           0.138   Prob(JB):                        0.712
# Kurtosis:                       2.317   Cond. No.                         8.87
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
dataset.dropna()
# Out:
#      R&DSpend  Administration  MarketingSpend       State     Profit
# 0   165349.20       136897.80       471784.10    New York  192261.83
# 1   162597.70       151377.59       443898.53  California  191792.06
# 2   153441.51       101145.55       407934.54     Florida  191050.39
# 3   144372.41       118671.85       383199.62    New York  182901.99
# 4   142107.34        91391.77       366168.42     Florida  166187.94
# 5   131876.90        99814.71       362861.36    New York  156991.12
# 6   134615.46       147198.87       127716.82  California  156122.51
# 7   130298.13       145530.06       323876.68     Florida  155752.60
# 8   120542.52       148718.95       311613.29    New York  152211.77
# 9   123334.88       108679.17       304981.62  California  149759.96
# 10  101913.08       110594.11       229160.95     Florida  146121.95
# 11  100671.96        91790.61       249744.55  California  144259.40
# 12   93863.75       127320.38       249839.44     Florida  141585.52
# 13   91992.39       135495.07       252664.93  California  134307.35
# 14  119943.24       156547.42       256512.92     Florida  132602.65
# 15  114523.61       122616.84       261776.23    New York  129917.04
# 16   78013.11       121597.55       264346.06  California  126992.93
# 17   94657.16       145077.58       282574.31    New York  125370.37
# 18   91749.16       114175.79       294919.57     Florida  124266.90
# 19   86419.70       153514.11            0.00    New York  122776.86
# 20   76253.86       113867.30       298664.47  California  118474.03
# 21   78389.47       153773.43       299737.29    New York  111313.02
# 22   73994.56       122782.75       303319.26     Florida  110352.25
# 23   67532.53       105751.03       304768.73     Florida  108733.99
# 24   77044.01        99281.34       140574.81    New York  108552.04
# 25   64664.71       139553.16       137962.62  California  107404.34
# 26   75328.87       144135.98       134050.07     Florida  105733.54
# 27   72107.60       127864.55       353183.81    New York  105008.31
# 28   66051.52       182645.56       118148.20     Florida  103282.38
# 29   65605.48       153032.06       107138.38    New York  101004.64
# 30   61994.48       115641.28        91131.24     Florida   99937.59
# 31   61136.38       152701.92        88218.23    New York   97483.56
# 32   63408.86       129219.61        46085.25  California   97427.84
# 33   55493.95       103057.49       214634.81     Florida   96778.92
# 34   46426.07       157693.92       210797.67  California   96712.80
# 35   46014.02        85047.44       205517.64    New York   96479.51
# 36   28663.76       127056.21       201126.82     Florida   90708.19
# 37   44069.95        51283.14       197029.42  California   89949.14
# 38   20229.59        65947.93       185265.10    New York   81229.06
# 39   38558.51        82982.09       174999.30  California   81005.76
# 40   28754.33       118546.05       172795.67  California   78239.91
# 41   27892.92        84710.77       164470.71     Florida   77798.83
# 42   23640.93        96189.63       148001.11  California   71498.49
# 43   15505.73       127382.30        35534.17    New York   69758.98
# 44   22177.74       154806.14        28334.72  California   65200.33
# 45    1000.23       124153.04         1903.93    New York   64926.08
# 46    1315.46       115816.21       297114.46     Florida   49490.75
# 47       0.00       135426.92            0.00  California   42559.73
# 48     542.05        51743.15            0.00    New York   35673.41
# 49       0.00       116983.80        45173.06  California   14681.40

# %%
fig, ax = plt.subplots(figsize=(12,8))
fig = sm.graphics.influence_plot(model, ax=ax, criterion="cooks")   #influence plot

# %%
fig, ax = plt.subplots(figsize=(12,8))  #Partial Regression Plots (Duncan)
fig = sm.graphics.plot_partregress("Profit", "MarketingSpend", ["Profit", "MarketingSpend"], data=dataset, ax=ax)

# %%
fig, ax = plt.subplots(figsize=(12,8))   #Partial Regression Plots (Duncan)
fig = sm.graphics.plot_partregress("Profit","Administration", ["Profit", "Administration"], data=dataset, ax=ax)

# %%
fig = plt.figure(figsize=(12,8))  #Partial Regression Plot
fig = sm.graphics.plot_partregress_grid(model, fig=fig)

# %%
fig = plt.figure(figsize=(12, 8))   #CCPR plot
fig = sm.graphics.plot_ccpr_grid(model, fig=fig)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Get variables for which to compute VIF and add intercept term
X = dataset[['R&DSpend','MarketingSpend','Administration']]
X['dataset'] = 1

# Compute and view VIF
#vif = pd.____
#vif["variables"] = X.____
#vif["VIF"] = [____(X.values, i) for i in range(X.shape[1])]
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
